# %%
# ===============================================================================================================#
# Copyright 2023 Infosys Ltd.                                                                          #
# Use of this source code is governed by Apache License Version 2.0 that can be found in the LICENSE file or at  #
# http://www.apache.org/licenses/                                                                                #
# ===============================================================================================================#

# %% [markdown]
# # 1. Installation

# %% [markdown]
# ##### Install required libraries (python >3.10.5)

# %%
# !python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade ../../lib/infy_ocr_generator-0.0.13-py3-none-any.whl[tesseract,aws,afr]
# !pip install --upgrade ../../lib/infy_ocr_parser-0.0.17-py3-none-any.whl
# !pip install --upgrade ../../lib/infy_field_extractor-0.0.13-py3-none-any.whl
# !pip install --upgrade ../../lib/infy_table_extractor-0.0.12-py3-none-any.whl
# !pip install --upgrade ../../lib/infy_common_utils-0.0.10-py3-none-any.whl

# %% [markdown]
# <hr/>

# %% [markdown]
# # 2. Maintenance (Optional)
# #### <span style='color:red'><b>NOTE: This section is for maintenance purpose <i>only</i> so you may skip.</b></span>

# %% [markdown]
# #### 2.1. Clear output from all notebook files

# %%
from _internal_utils.notebook_util import NotebookUtil

NB_ROOT_FOLDER_PATH = '.'
EXCLUDE_NB_FILE_LIST = ['installation.ipynb']
NotebookUtil.clear_output(NB_ROOT_FOLDER_PATH, EXCLUDE_NB_FILE_LIST, dry_run_mode=False)
